# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
dataset = tf.keras.datasets.cifar10
(X_train, Y_train), (X_test, Y_test) = dataset.load_data()
X_train = X_train.reshape(50000,3072)
X_train, X_test, Y_train, Y_test = train_test_split(X_train, Y_train, test_size=0.1, random_state=24)

# %%
model = tf.keras.models.Sequential([
        tf.keras.layers.Dense(64, input_dim = 3072, activation='relu'),
        tf.keras.layers.Dense(32, activation='relu'),
        tf.keras.layers.Dense(10, activation='softmax')
])

# %%
model.compile(  optimizer=tf.keras.optimizers.Adam(),
                loss=tf.keras.losses.sparse_categorical_crossentropy,
                metrics=['accuracy'])

# %%
model_output = model.fit(X_train, Y_train, epochs=7)
model.evaluate(X_test, Y_test)
# Out:
# Epoch 1/7
# 1407/1407 [==============================] - 4s 3ms/step - loss: 2.3028 - accuracy: 0.0974
# Epoch 2/7
# 1407/1407 [==============================] - 4s 3ms/step - loss: 2.3028 - accuracy: 0.0975
# Epoch 3/7
# 1407/1407 [==============================] - 4s 3ms/step - loss: 2.3028 - accuracy: 0.0973
# Epoch 4/7
# 1407/1407 [==============================] - 4s 3ms/step - loss: 2.3028 - accuracy: 0.0979
# Epoch 5/7
# 1407/1407 [==============================] - 4s 3ms/step - loss: 2.3028 - accuracy: 0.0988
# Epoch 6/7
# 1407/1407 [==============================] - 4s 3ms/step - loss: 2.3028 - accuracy: 0.0975
# Epoch 7/7
# 1407/1407 [==============================] - 4s 3ms/step - loss: 2.3028 - accuracy: 0.0981
# 157/157 [==============================] - 0s 1ms/step - loss: 2.3029 - accuracy: 0.0984
# [2.3028640747070312, 0.09839999675750732]

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))
ax1.plot(model_output.history['loss'])
ax1.set_title("Loss CNN")
ax2.plot(model_output.history['accuracy'])
ax2.set_title("Accuracy CNN")
plt.show()
