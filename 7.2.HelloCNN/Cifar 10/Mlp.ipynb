# %%
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
dataset = tf.keras.datasets.cifar10
(X_train, Y_train), (X_test, Y_test) = dataset.load_data()
X_train, X_test, X_test = X_train / 255.0, X_test / 255.0, X_test / 255.0

# %%
model = tf.keras.models.Sequential([
     tf.keras.layers.Flatten(input_shape=(32, 32, 3)),
     tf.keras.layers.Dense(128, activation="relu"),
     tf.keras.layers.Dense(10, activation="softmax")
])

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss = tf.keras.losses.sparse_categorical_crossentropy,
              metrics = ['accuracy'])

# %%
model_output = model.fit(X_train, Y_train, epochs=15)

model.evaluate(X_test, Y_test)
# Out:
# Epoch 1/15
# 1563/1563 [==============================] - 11s 7ms/step - loss: 1.6895 - accuracy: 0.3958
# Epoch 2/15
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.6732 - accuracy: 0.3999
# Epoch 3/15
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.6599 - accuracy: 0.4044
# Epoch 4/15
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.6516 - accuracy: 0.4102
# Epoch 5/15
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.6416 - accuracy: 0.4144
# Epoch 6/15
# 1563/1563 [==============================] - 7s 4ms/step - loss: 1.6363 - accuracy: 0.4175
# Epoch 7/15
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.6286 - accuracy: 0.4187
# Epoch 8/15
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.6200 - accuracy: 0.4220
# Epoch 9/15
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.6156 - accuracy: 0.4253
# Epoch 10/15
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.6105 - accuracy: 0.4290
# Epoch 11/15
# 1563/1563 [==============================] - 7s 5ms/step - loss: 1.6059 - accuracy: 0.4299
# Epoch 12/15
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.5996 - accuracy: 0.4326
# Epoch 13/15
# 1563/1563 [==============================] - 11s 7ms/step - loss: 1.5970 - accuracy: 0.4342
# Epoch 14/15
# 1563/1563 [==============================] - 11s 7ms/step - loss: 1.5901 - accuracy: 0.4358
# Epoch 15/15
# 1563/1563 [==============================] - 12s 8ms/step - loss: 1.5897 - accuracy: 0.4360
# 313/313 [==============================] - 1s 2ms/step - loss: 1.6253 - accuracy: 0.4197
# [1.6252784729003906, 0.4196999967098236]

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))
ax1.plot(model_output.history['loss'])
ax1.set_title("Loss CNN")
ax2.plot(model_output.history['accuracy'])
ax2.set_title("Accuracy CNN")
plt.show()
