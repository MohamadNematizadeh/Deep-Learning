# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
dataset = tf.keras.datasets.cifar10
(X_train, Y_train), (X_test, Y_test) = dataset.load_data()
X_train, X_test, Y_train, Y_test = train_test_split(X_train, Y_train, test_size=0.1, random_state=33)

X_train, X_test, X_test = X_train / 255.0, X_test / 255.0, X_test / 255.0

# %%
model = tf.keras.models.Sequential([
     tf.keras.layers.Flatten(input_shape=(32, 32, 3)),
     tf.keras.layers.Dense(128, activation="relu"),
     tf.keras.layers.Dense(10, activation="softmax")
])

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss=tf.keras.losses.sparse_categorical_crossentropy,
              metrics=["accuracy"])

# %%
model_output = model.fit(X_train, Y_train, epochs=15)

model.evaluate(X_test, Y_test)
# Out:
# Epoch 1/15
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.9218 - accuracy: 0.3126
# Epoch 2/15
# 1407/1407 [==============================] - 8s 5ms/step - loss: 1.7806 - accuracy: 0.3650
# Epoch 3/15
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.7322 - accuracy: 0.3841
# Epoch 4/15
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.7000 - accuracy: 0.3946
# Epoch 5/15
# 1407/1407 [==============================] - 9s 7ms/step - loss: 1.6772 - accuracy: 0.4031
# Epoch 6/15
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.6578 - accuracy: 0.4089
# Epoch 7/15
# 1407/1407 [==============================] - 9s 6ms/step - loss: 1.6427 - accuracy: 0.4130
# Epoch 8/15
# 1407/1407 [==============================] - 11s 7ms/step - loss: 1.6297 - accuracy: 0.4179
# Epoch 9/15
# 1407/1407 [==============================] - 10s 7ms/step - loss: 1.6226 - accuracy: 0.4210
# Epoch 10/15
# 1407/1407 [==============================] - 9s 7ms/step - loss: 1.6164 - accuracy: 0.4236
# Epoch 11/15
# 1407/1407 [==============================] - 11s 8ms/step - loss: 1.6085 - accuracy: 0.4257
# Epoch 12/15
# 1407/1407 [==============================] - 9s 6ms/step - loss: 1.6000 - accuracy: 0.4281
# Epoch 13/15
# 1407/1407 [==============================] - 9s 6ms/step - loss: 1.5947 - accuracy: 0.4286
# Epoch 14/15
# 1407/1407 [==============================] - 9s 6ms/step - loss: 1.5927 - accuracy: 0.4324
# Epoch 15/15
# 1407/1407 [==============================] - 8s 6ms/step - loss: 1.5874 - accuracy: 0.4343
# 157/157 [==============================] - 0s 1ms/step - loss: 1.6359 - accuracy: 0.4132
# [1.635927677154541, 0.4131999909877777]

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))
ax1.plot(model_output.history['loss'])
ax1.set_title("Loss CNN")
ax2.plot(model_output.history['accuracy'])
ax2.set_title("Accuracy CNN")
plt.show()
