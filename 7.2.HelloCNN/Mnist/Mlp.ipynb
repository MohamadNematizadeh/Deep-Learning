# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
mnist = tf.keras.datasets.mnist
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()

X_train, X_test = X_train / 255.0, X_test / 255.0
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], X_train.shape[2], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], X_test.shape[2], 1)
X_train = X_train.reshape(60000,784)
X_test = X_test.reshape(10000,784)

# %%
model = tf.keras.models.Sequential([
        tf.keras.layers.Dense(64, input_dim = X_train.shape[1], activation='relu'),
        tf.keras.layers.Dense(32, activation='relu'),
        tf.keras.layers.Dense(10, activation='softmax'),
])

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss = tf.keras.losses.sparse_categorical_crossentropy,
              metrics = ['accuracy'])

# %%
model_output = model.fit(X_train, Y_train, epochs = 16)
model.evaluate(X_test, Y_test)
# Out:
# Epoch 1/16
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3015 - accuracy: 0.9120
# Epoch 2/16
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1386 - accuracy: 0.9585
# Epoch 3/16
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1010 - accuracy: 0.9692
# Epoch 4/16
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0805 - accuracy: 0.9755
# Epoch 5/16
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0684 - accuracy: 0.9787
# Epoch 6/16
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0573 - accuracy: 0.9823
# Epoch 7/16
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0480 - accuracy: 0.9848
# Epoch 8/16
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0419 - accuracy: 0.9863
# Epoch 9/16
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.0367 - accuracy: 0.9878
# Epoch 10/16
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.0321 - accuracy: 0.9894
# Epoch 11/16
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0279 - accuracy: 0.9909
# Epoch 12/16
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0247 - accuracy: 0.9919
# Epoch 13/16
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0221 - accuracy: 0.9925
# Epoch 14/16
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0214 - accuracy: 0.9926
# Epoch 15/16
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0198 - accuracy: 0.9936
# Epoch 16/16
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.0193 - accuracy: 0.9939
# 313/313 [==============================] - 1s 1ms/step - loss: 0.1219 - accuracy: 0.9719
# [0.12194181978702545, 0.9718999862670898]

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))
ax1.plot(model_output.history['loss'])
ax1.set_title("Loss Mlp")
ax2.plot(model_output.history['accuracy'])
ax2.set_title("Accuracy Mlp")
plt.show()
